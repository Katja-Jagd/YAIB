# %%
import gzip

i = 'CHARTEVENTS'
# File to test
file_old = f"/work3/s185395/YAIB-cohorts/data/mimic_old/{i}.csv.gz"
file_new = f"/work3/s185395/YAIB-cohorts/data/mimic/{i}.csv.gz"

with gzip.open(file_new, 'rt') as f:
    header_new = next(f).strip()
    print(header_new)

with gzip.open(file_old, 'rt') as f:
    header_old = next(f).strip()
    #print(header_old)
# Out:
# ROW_ID,SUBJECT_ID,HADM_ID,ICUSTAY_ID,ITEMID,CHARTTIME,STORETIME,CGID,VALUE,VALUENUM,VALUEUOM,WARNING,ERROR,RESULTSTATUS,STOPPED
